# %%
import os
from IPython.display import display, HTML
# MathTeachingAssistant.py has all libraries to interact with openai and to produce output files
from MathTeachingAssistant import *
from DocumentProcessor import *

# %%
origin='/mnt/ssd_disk/Math_content_vimschool/'
destination='/mnt/ssd_disk/Math_content_vimschool/10th_grade'

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Instantiate the assistant

# %%
assistant = MathTeachingAssistant('HIGHSCHOOL-SCOPE.xlsx','Geo-B1G-M.pdf')

# %%
assistant.preprocess_dataframe()
# Out:
#                                                                            Strands  \
# Week    Topic
# Week 1  The Builiding Blocks of Geometry                  GEOMETRIC REASONING (GR)
#         The Builiding Blocks of Geometry                  GEOMETRIC REASONING (GR)
#         The Builiding Blocks of Geometry                  GEOMETRIC REASONING (GR)
# Week 2  Logic and Proofs: Construction of Arguments   LOGIC & DISCRETE THEORY (LT)
#         Logic and Proofs: Construction of Arguments   LOGIC & DISCRETE THEORY (LT)
# ...                                                                            ...
# Week 32 Review and Applied Problems on Trigonometry               TRIGONOMETRY (T)
# Week 33 Review and Applied Problems on Vectors       NUMBER SENSE OPERATIONS (NSO)
#         Review and Applied Problems on Vectors       NUMBER SENSE OPERATIONS (NSO)
#         Review and Applied Problems on Vectors       NUMBER SENSE OPERATIONS (NSO)
# ...

# %%
# api_key='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'
#Assistant id: asst_vpJquOPsYj6h70RH4KlaCWPD

# %%
for week,title in dict(assistant.df.index).items(): #for week,title in tuple(dict(assistant.df.index).items())[:3]:#
    if week=='Week 10':
        print(week,title)
# Out:
# Week 10 Cross sections of 3D figures and Revolution solids (by rotating 2D figures)

# %% [markdown]
# Run the process

# %%
# assistant.preprocess_dataframe()
assistant.setup_openai()
for week,title in dict(assistant.df.index).items(): #for week,title in tuple(dict(assistant.df.index).items())[:3]:#
#     if week=='Week 10':
        print(week,title)
        assistant.process_interactions(week,title)
# Out:
# Enter API key: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
# Do you have an assistant (Y or N)Y
# Write assistant idasst_vpJquOPsYj6h70RH4KlaCWPD
# Retrieved existing assistant: asst_vpJquOPsYj6h70RH4KlaCWPD
# Week 10 Cross sections of 3D figures and Revolution solids (by rotating 2D figures)
# Saved to presentation_Week 10.html
# Saved to workshop_Week 10.tex
# Saved to test_Week 10.tex
# Saved to forum_Week 10.txt
# All interactions completed and outputs saved!

# %% [markdown]
# Processing the files by converting into compilable latex, then word or pptx

# %% [markdown]
# Executed in terminal
# for i in {1..33}; do sed -i '/alph/c\\begin{enumerate}' test_Week\ ${i}.tex;done
# //it's \begin{enumerate}[a.]

# %%
try:
    !(mkdir Content)
    !(rm FORUMS_MATH_10TH.txt)
    !(echo "FORUM QUESTIONS" > FORUMS_MATH_10TH.txt)
except Exception as e:
    print(f"Error: {e}")
# Out:
# mkdir: cannot create directory ‘Content’: File exists

# %%
for i,(week,title) in enumerate(dict(assistant.df.index).items()):
    title_up=title.replace(" ","-").upper()
    week_up=week.upper()
    processor = DocumentProcessor()
    text=f"10th Grade Workshop Week {i+1}\n\n\n"
    processor.insert_string_into_docx('template_workshops.docx', text, f'Content/template_workshop_{week}_o.docx',align=1)#f'Content/workshop_Week 1_o.docx')
    text=f"10th Grade Week {i+1} Test\n"
    processor.insert_string_into_docx('template_tests.docx', text, f'Content/template_tests_{week}_o.docx',align=1)
    text2='''Instructions:\n
    - Read each question carefully and select the best answer.
    - Choose the option that corresponds to the correct solution.
    - There is only one correct answer for each question.
    - Utilize calculators as needed for computations.
    - Have the necessary materials: pencils, erasers and a piece of paper.'''
    processor.insert_string_into_docx(f'Content/template_tests_{week}_o.docx', text2, f'Content/template_tests_{week}_o.docx',align=0)#f'Content/workshop_Week 1_o.docx')

    #     print(f'{destination}/Content/W-{i+1}-{title}.docx')
# !(mv 'Content/FORUMS_MATH_10TH.docx' '{destination}/Content/FORUMS_MATH_10TH.docx')

# %%
for i,(week,title) in enumerate(dict(assistant.df.index).items()): #for week,title in tuple(dict(assistant.df.index).items())[:3]:
    title_up=title.replace(" ","-").upper()
    week_up=week.upper()
    print(week,title)
# Example usage
    processor = DocumentProcessor()
    
    # Extract LaTeX content
    processor.extract_latex_content(f'workshop_{week}.tex', f'workshop_{week}_o.tex')
    processor.extract_latex_content(f'test_{week}.tex', f'test_{week}_o.tex')
    
    # Convert a file
    processor.conversion_to_office(f'workshop_{week}_o.tex','docx')
    processor.conversion_to_office(f'test_{week}_o.tex','docx')
    processor.conversion_to_office(f'presentation_{week}.html','pptx')
    
    # Insert content into a template
    processor.insert_content_into_template(
        content_docx=f'workshop_{week}_o.docx',
        template_docx=f'Content/template_workshop_{week}_o.docx',
        output_docx=f'{destination}/Content/W-{i+1}-WSP-{title_up}.docx'#f'Content/workshop_{week}_o.docx'
    )
        # Insert content into a template
    processor.insert_content_into_template(
        content_docx=f'test_{week}_o.docx',
        template_docx=f'Content/template_tests_{week}_o.docx',
        output_docx=f'{destination}/Content/W-{i+1}-TEST-{title_up}.docx'#f'Content/test_{week}_o.docx'
    )
    !(echo -e "\n\n\n\n{week}\n" >> FORUMS_MATH_10TH.txt)
    !(cat 'forum_{week}.txt' >> FORUMS_MATH_10TH.txt)
    #Moving into contents folder
    !(mv 'presentation_{week}.pptx' 'Content/presentation_{week}_o.pptx')
processor.conversion_to_office(f'FORUMS_MATH_10TH.txt','docx')
!(mv 'FORUMS_MATH_10TH.docx' '{destination}/Content/FORUMS_MATH_10TH.docx')#'Content/FORUMS_MATH_10TH.docx')
#     processor.insert_content_into_template(
#         content_docx=f'f'presentation_{week}.pptx',
#         template_docx='template_presentation.pptx',
#         output_docx='Content/presentation_{week}_o.pptx'
#     )
# Out:
# Week 1 The Builiding Blocks of Geometry
# LaTeX content successfully extracted to workshop_Week 1_o.tex
# LaTeX content successfully extracted to test_Week 1_o.tex
# Successfully converted workshop_Week 1_o.tex to workshop_Week 1_o.docx
# Successfully converted test_Week 1_o.tex to test_Week 1_o.docx
# Conversion error: Command 'pandoc 'presentation_Week 1.html' -o 'presentation_Week 1.pptx'' returned non-zero exit status 1.
# Standard Output:
# Standard Error: pandoc: presentation_Week 1.html: openBinaryFile: does not exist (No such file or directory)
#
# Content successfully inserted into /mnt/ssd_disk/Math_content_vimschool/10th_grade/Content/W-1-WSP-THE-BUILIDING-BLOCKS-OF-GEOMETRY.docx
# Content successfully inserted into /mnt/ssd_disk/Math_content_vimschool/10th_grade/Content/W-1-TEST-THE-BUILIDING-BLOCKS-OF-GEOMETRY.docx
# mv: cannot stat 'presentation_Week 1.pptx': No such file or directory
# Week 2 Logic and Proofs: Construction of Arguments
# ...

# %% [markdown]
# Change of file names

# %%
for i,(week,title) in enumerate(dict(assistant.df.index).items()):
    title_up=title.replace(" ","-").upper()
    week_up=week.upper()
    print(f'{destination}/Content/W-{i+1}-{title}.docx')
    !(mv 'presentation_{week}.html' '{destination}/Content/{week_up}-{title_up}.html')
    processor = DocumentProcessor()
    text=f"\n\nBenton:\n\nHello students, in this week's lesson we are going to talk about {title}. Are you ready to begin?" 
    processor.insert_string_into_docx('template_audios.docx', text, f'{destination}/Content/W-{i+1}-audio_transcript.docx')
# !(mv 'Content/FORUMS_MATH_10TH.docx' '{destination}/Content/FORUMS_MATH_10TH.docx')
# Out:
# /mnt/ssd_disk/Math_content_vimschool/10th_grade/Content/W-1-The Builiding Blocks of Geometry.docx
# mv: cannot stat 'presentation_Week 1.html': No such file or directory
# /mnt/ssd_disk/Math_content_vimschool/10th_grade/Content/W-2-Logic and Proofs: Construction of Arguments.docx
# mv: cannot stat 'presentation_Week 2.html': No such file or directory
# /mnt/ssd_disk/Math_content_vimschool/10th_grade/Content/W-3-Unlocking the Secrets of Lines and Angles.docx
# mv: cannot stat 'presentation_Week 3.html': No such file or directory
# /mnt/ssd_disk/Math_content_vimschool/10th_grade/Content/W-4-Triangle Mysteries: Unveiling Congruence and Similarity.docx
# mv: cannot stat 'presentation_Week 4.html': No such file or directory
# /mnt/ssd_disk/Math_content_vimschool/10th_grade/Content/W-5-Exploring Properties of Parallelograms and Trapezoids.docx
# mv: cannot stat 'presentation_Week 5.html': No such file or directory
# ...

# %%
# import sys

# def append_html_to_markdown(html_file, markdown_file, text=''):
#     with open(html_file, 'r') as html:
#         html_content = html.read()
    
#     with open(markdown_file, 'r') as md:
#         markdown_lines = md.readlines()
    
#     graph_line_index = markdown_lines.index('graph TD;')
    
#     if text:
#         markdown_lines.insert(graph_line_index + 1, f"{text}\n")
    
#     markdown_lines.insert(graph_line_index + (2 if text else 1), html_content + '\n')
    
#     with open(markdown_file, 'w') as md:
#         md.writelines(markdown_lines)

# %%
# def main():
#     if len(sys.argv) < 3 or len(sys.argv) > 4:
#         print("Usage: python script.py <html_file> <markdown_file> [text]")
#         sys.exit(1)
#     html_file=f'{destination}/Content/WEEK 1-THE-BUILIDING-BLOCKS-OF-GEOMETRY.html'
#     markdown_file=f'{destination}/Content/diagrams.md'
#     text='WEEK 1'
# #     text = sys.argv[3] if len(sys.argv) == 4 else ''
# #    html_file = sys.argv[1]
# #     markdown_file = sys.argv[2]
    
#     append_html_to_markdown(html_file, markdown_file, text)

# %%
if __name__ == '__main__':
    main()

# %%
sys.argv
